# %% [markdown]
# # Лекция 3: Библиотеки для глубинного обучения. Примитивы фремворка Pytorch.

# %% [markdown]
# #        Пример обучения нейронной сети в numpy

# %%
# -*- coding: utf-8 -*-
import numpy as np

# N - размер батча; D_in - размерность входа;
# H - скрытая размероность; D_out размерность выхода.
N, D_in, H, D_out = 64, 1000, 100, 10

# Инициализируем вход и выход из нормального распределения
x = np.random.randn(N, D_in)
y = np.random.randn(N, D_out)

# Инициализируем веса из нормального распределения
w1 = np.random.randn(D_in, H)
w2 = np.random.randn(H, D_out)

learning_rate = 1e-6
epochs = 500
for t in xrange(epochs):
    h = x.dot(w1)
    h_relu = np.maximum(h, 0)
    y_pred = h_relu.dot(w2)
    loss = np.square(y_pred - y).sum()
    print(t, loss)

    grad_y_pred = 2.0 * (y_pred - y) 
    grad_w2 = h_relu.T.dot(grad_y_pred)
    grad_h_relu = grad_y_pred.dot(w2.T)
    grad_h = grad_h_relu.copy()
    grad_h[h < 0] = 0
    grad_w1 = x.T.dot(grad_h)

    w1 -= learning_rate * grad_w1
    w2 -= learning_rate * grad_w2
# Out:
# (0, 41859566.38522698)
# (1, 47397469.966075629)
# (2, 55157354.249319047)
# (3, 50830339.774664581)
# (4, 32197600.107160471)
# (5, 13751907.505895544)
# (6, 5088859.0277813543)
# (7, 2311171.6387022827)
# (8, 1433665.3726479863)
# (9, 1068341.8897400945)
# (10, 856406.37146082695)
# (11, 706281.1417334025)
# (12, 590657.57166276313)
# (13, 498556.04507106205)
# (14, 424053.32991746493)
# (15, 363070.66552583728)
# (16, 312732.1992073413)
# (17, 270841.64208571881)
# (18, 235760.45083094478)
# (19, 206166.86190719134)
# (20, 181059.48925840171)
# (21, 159631.86630629725)
# (22, 141257.34951139113)
# (23, 125416.8063724167)
# (24, 111695.82050353926)
# (25, 99781.314465385352)
# (26, 89388.638581276085)
# (27, 80292.672241151653)
# (28, 72292.406363056682)
# (29, 65236.348046603831)
# (30, 58996.796005008538)
# (31, 53460.59752593821)
# (32, 48540.32667259992)
# (33, 44155.400496976552)
# (34, 40234.73904473921)
# (35, 36720.633896067258)
# (36, 33565.002887538321)
# (37, 30725.636853274002)
# (38, 28164.853306584144)
# (39, 25850.26672366586)
# (40, 23755.405965670863)
# (41, 21857.38910110428)
# (42, 20134.875329813753)
# (43, 18568.291153728496)
# (44, 17141.498448195867)
# (45, 15839.734532297101)
# (46, 14649.581875567652)
# (47, 13561.00482452912)
# (48, 12563.911960370602)
# (49, 11649.732983226659)
# (50, 10810.845450889101)
# (51, 10039.691342196613)
# (52, 9330.5351461680621)
# (53, 8677.4299825856651)
# (54, 8075.2838281241056)
# (55, 7519.8343576316674)
# (56, 7006.9554236449712)
# (57, 6532.9752575649636)
# (58, 6094.4883310353189)
# (59, 5688.6532130256619)
# (60, 5312.7279252980861)
# (61, 4964.2454960890718)
# (62, 4641.3258031784571)
# (63, 4341.6152718199291)
# (64, 4063.2707383511693)
# (65, 3804.5304324148547)
# (66, 3563.8801954267865)
# (67, 3340.0108512407987)
# (68, 3131.5577192275841)
# (69, 2937.2878830886657)
# (70, 2756.15876527407)
# (71, 2587.1988780048778)
# (72, 2429.5296488733093)
# (73, 2282.2676800573195)
# (74, 2144.6695968563754)
# (75, 2016.0730451894196)
# (76, 1895.7768815791585)
# (77, 1783.2152419479307)
# (78, 1677.9667930855926)
# (79, 1579.7061138498248)
# (80, 1487.644481891075)
# (81, 1401.3500075412221)
# (82, 1320.436349517425)
# (83, 1244.540741071145)
# (84, 1173.348337428097)
# (85, 1106.4874010196877)
# (86, 1043.6864273650972)
# (87, 984.67943233930828)
# (88, 929.23709948327871)
# (89, 877.2106387138183)
# (90, 828.3120004426504)
# (91, 782.31632502071216)
# (92, 739.03011171793344)
# (93, 698.28060162526822)
# (94, 659.93005112616561)
# (95, 623.7876961868086)
# (96, 589.73534323575132)
# (97, 557.65201461577044)
# (98, 527.41124578789459)
# (99, 498.9025260988808)
# (100, 472.0132103069725)
# (101, 446.64105674163034)
# (102, 422.70859375404359)
# (103, 400.12542954679475)
# (104, 378.80014209830233)
# (105, 358.66184370574661)
# (106, 339.64692380807639)
# (107, 321.68207247885948)
# (108, 304.71310656105766)
# (109, 288.68183615324079)
# (110, 273.53568419201531)
# (111, 259.21914556187454)
# (112, 245.6834723091356)
# (113, 232.88258134085953)
# (114, 220.77307182938495)
# (115, 209.31533164355363)
# (116, 198.47538260275772)
# (117, 188.21869248260398)
# (118, 178.50820043138316)
# (119, 169.31724455942526)
# (120, 160.61737141239948)
# (121, 152.37863465986868)
# (122, 144.57725517869918)
# (123, 137.18206791272149)
# (124, 130.17807381782882)
# (125, 123.54302522374867)
# (126, 117.25645933422871)
# (127, 111.29902029948644)
# (128, 105.65296014949848)
# (129, 100.30746091450912)
# (130, 95.241403455071946)
# (131, 90.43806190758194)
# (132, 85.88287790472782)
# (133, 81.562170004061556)
# (134, 77.46485977042839)
# (135, 73.579241639215326)
# (136, 69.893191262213463)
# (137, 66.396281067222418)
# (138, 63.078481771304048)
# (139, 59.931376642078988)
# (140, 56.945087872859894)
# (141, 54.110494055346152)
# (142, 51.419699930936559)
# (143, 48.865652010570003)
# (144, 46.441350991455671)
# (145, 44.139841710161676)
# (146, 41.954526849375064)
# (147, 39.87972287597124)
# (148, 37.910347807530052)
# (149, 36.039494705631583)
# (150, 34.262499846765593)
# (151, 32.57478681718294)
# (152, 30.972090748906936)
# (153, 29.449481134863966)
# (154, 28.003280491575097)
# (155, 26.629345924123321)
# (156, 25.324103032300783)
# (157, 24.083756505305317)
# (158, 22.905043389360564)
# (159, 21.784989018506863)
# (160, 20.720672031392809)
# (161, 19.709170149582274)
# (162, 18.747837194671625)
# (163, 17.834061418301857)
# (164, 16.965541608431302)
# (165, 16.139943978978103)
# (166, 15.355000794723674)
# (167, 14.60905462335843)
# (168, 13.899600980686547)
# (169, 13.225147555588503)
# (170, 12.58390885566453)
# (171, 11.974204939523684)
# (172, 11.394350857230755)
# (173, 10.843054564026067)
# (174, 10.318716567498436)
# (175, 9.8202026481053721)
# (176, 9.3459788896140914)
# (177, 8.8949943327229448)
# (178, 8.4659417202716831)
# (179, 8.0578072213243104)
# (180, 7.6697124095651077)
# (181, 7.3004810543756484)
# (182, 6.9491782699264952)
# (183, 6.6149626097741203)
# (184, 6.2970305463875782)
# (185, 5.9945880307647901)
# (186, 5.7067647892425928)
# (187, 5.4329337646956697)
# (188, 5.1723902761795797)
# (189, 4.9244514140864872)
# (190, 4.6885550253130104)
# (191, 4.4640535676302981)
# (192, 4.2504009521745152)
# (193, 4.0470522462440472)
# (194, 3.853540780702938)
# (195, 3.6693883592394649)
# (196, 3.4940931882520898)
# (197, 3.3272560479798465)
# (198, 3.1685132168533001)
# (199, 3.017402633710081)
# (200, 2.8735461090751642)
# (201, 2.7365909951116913)
# (202, 2.6062311563096161)
# (203, 2.482123951477254)
# (204, 2.3639859307505691)
# (205, 2.2515555562421206)
# (206, 2.1444858496668644)
# (207, 2.0425499186901055)
# (208, 1.9455017664794885)
# (209, 1.8531310330119988)
# (210, 1.7651462246025007)
# (211, 1.6813710476558388)
# (212, 1.6016172518180551)
# (213, 1.5256807454309258)
# (214, 1.4533766778685822)
# (215, 1.3845106530830245)
# (216, 1.3189353070984102)
# (217, 1.256483957763979)
# (218, 1.1970169249164311)
# (219, 1.1403909674294348)
# (220, 1.0864579375010179)
# (221, 1.0350906847395283)
# (222, 0.98616855705739748)
# (223, 0.93957518559794639)
# (224, 0.89519632912992364)
# (225, 0.85293301046919012)
# (226, 0.81268104587082579)
# (227, 0.77433802591932177)
# (228, 0.73781345369532936)
# (229, 0.70302789634982199)
# (230, 0.66989522554176339)
# (231, 0.63832868652970576)
# (232, 0.60826152522272725)
# (233, 0.57962063346244219)
# (234, 0.55233265180702273)
# (235, 0.52634109562773268)
# (236, 0.50157885049169193)
# (237, 0.47798939288090903)
# (238, 0.45551409596822179)
# (239, 0.4341017105918345)
# (240, 0.41370510748752448)
# (241, 0.39426841034672189)
# (242, 0.37575066164829973)
# (243, 0.35811051923581566)
# (244, 0.34130443201710592)
# (245, 0.32529093898468109)
# (246, 0.31003038571240377)
# (247, 0.29549150504126726)
# (248, 0.28163762898083133)
# (249, 0.26843845152695323)
# (250, 0.25586164422139329)
# (251, 0.24387634181228679)
# (252, 0.23245443386915782)
# (253, 0.22156975001923396)
# (254, 0.21120009989626265)
# (255, 0.20131705739205)
# (256, 0.19190311144079858)
# (257, 0.18292709096682641)
# (258, 0.17437490049176899)
# (259, 0.16622270109157156)
# (260, 0.15845379288459494)
# (261, 0.15104983168049946)
# (262, 0.14399427198772768)
# (263, 0.13726859656707838)
# (264, 0.130858927928728)
# (265, 0.12475032259649013)
# (266, 0.11892835810385013)
# (267, 0.11337916414054382)
# (268, 0.10809040371478848)
# (269, 0.10304983864367025)
# (270, 0.098244883636317781)
# (271, 0.093665728860975739)
# (272, 0.089300231830116761)
# (273, 0.085139978629366148)
# (274, 0.081173662126984014)
# (275, 0.077392863410085097)
# (276, 0.07378935632825348)
# (277, 0.070354703873391003)
# (278, 0.06708037303129874)
# (279, 0.063958907598990505)
# (280, 0.060983350433262709)
# (281, 0.058147068714563405)
# (282, 0.055442882087738954)
# (283, 0.052865000486571292)
# (284, 0.050408006774850231)
# (285, 0.048065890170821975)
# (286, 0.045832410114317573)
# (287, 0.043703172272473549)
# (288, 0.041673428912511953)
# (289, 0.039738348588061821)
# (290, 0.037893531798410471)
# (291, 0.036134581805134583)
# (292, 0.034457842613904908)
# (293, 0.032859144655663169)
# (294, 0.031334799348695777)
# (295, 0.029881484331781713)
# (296, 0.02849593729278569)
# (297, 0.027174845838511145)
# (298, 0.025915151273407724)
# (299, 0.024714210356665628)
# (300, 0.023569427474198917)
# (301, 0.022477618442514401)
# (302, 0.021436454712480228)
# (303, 0.020444089992507464)
# (304, 0.019497750384156968)
# (305, 0.018595184525314536)
# (306, 0.017734562047027336)
# (307, 0.016913920168854166)
# (308, 0.016131393394582177)
# (309, 0.015385270837020756)
# (310, 0.014673679101251043)
# (311, 0.013995132740835546)
# (312, 0.013348086897597367)
# (313, 0.012731131200546041)
# (314, 0.012142757185212382)
# (315, 0.011581736439393324)
# (316, 0.011046639120164308)
# (317, 0.01053645927956871)
# (318, 0.01004983917996953)
# (319, 0.0095857891842787372)
# (320, 0.0091432119840961674)
# (321, 0.0087211869992333754)
# (322, 0.0083187742548136746)
# (323, 0.0079349095542690755)
# (324, 0.0075688023978783339)
# (325, 0.0072196643299746828)
# (326, 0.0068867106984336762)
# (327, 0.0065691277962186597)
# (328, 0.0062662444779847653)
# (329, 0.0059773795977980512)
# (330, 0.0057019170157811463)
# (331, 0.0054391893975389016)
# (332, 0.0051885785033568468)
# (333, 0.0049495505974430139)
# (334, 0.0047215712495305116)
# (335, 0.0045041402151958692)
# (336, 0.0042967449423449711)
# (337, 0.0040989290731306156)
# (338, 0.0039102474702830802)
# (339, 0.0037302980556238301)
# (340, 0.0035586333706107321)
# (341, 0.0033949003555829591)
# (342, 0.0032387172474229071)
# (343, 0.003089756010441938)
# (344, 0.0029476953431455937)
# (345, 0.0028121534974367307)
# (346, 0.0026828643179583056)
# (347, 0.0025595424720789173)
# (348, 0.0024419300130804674)
# (349, 0.0023297229341572682)
# (350, 0.0022226757185486454)
# (351, 0.0021205709693372468)
# (352, 0.0020231637641932804)
# (353, 0.001930258582628732)
# (354, 0.0018416179301705411)
# (355, 0.0017570955143685961)
# (356, 0.0016764432682573292)
# (357, 0.0015994951657240454)
# (358, 0.0015261012237370549)
# (359, 0.0014560728863819341)
# (360, 0.0013892675814181606)
# (361, 0.0013255348996050573)
# (362, 0.0012647537770262996)
# (363, 0.0012067571166806414)
# (364, 0.0011514238125375979)
# (365, 0.0010986473055560166)
# (366, 0.0010482858477744946)
# (367, 0.0010002428558780745)
# (368, 0.0009544061378412435)
# (369, 0.00091067354222028286)
# (370, 0.00086894886070000349)
# (371, 0.00082914167912135576)
# (372, 0.00079116816518381809)
# (373, 0.00075493963047919776)
# (374, 0.00072037046043302657)
# (375, 0.00068738724975476702)
# (376, 0.00065591902831773534)
# (377, 0.00062589722756051117)
# (378, 0.00059725613395553005)
# (379, 0.0005699274937755077)
# (380, 0.00054385070315194847)
# (381, 0.00051897080348846825)
# (382, 0.0004952326725483244)
# (383, 0.00047258734154935077)
# (384, 0.0004509768686142508)
# (385, 0.00043035568533717622)
# (386, 0.00041068307849510312)
# (387, 0.00039191102941049048)
# (388, 0.00037400077534820717)
# (389, 0.00035690850328269435)
# (390, 0.00034059929012744737)
# (391, 0.00032503798196737311)
# (392, 0.0003101891221699882)
# (393, 0.00029602293515910039)
# (394, 0.00028250385382724787)
# (395, 0.00026960294750189072)
# (396, 0.00025729306418106852)
# (397, 0.00024554616628114849)
# (398, 0.00023433760203117845)
# (399, 0.00022364291076313009)
# (400, 0.00021343737445758042)
# (401, 0.00020369775802551353)
# (402, 0.0001944039070118627)
# (403, 0.00018553607759299017)
# (404, 0.00017707413770509583)
# (405, 0.00016899817010583476)
# (406, 0.00016129153377957955)
# (407, 0.00015393721305684266)
# (408, 0.0001469187697802221)
# (409, 0.00014022128675008399)
# (410, 0.00013383087029860514)
# (411, 0.00012773120669891811)
# (412, 0.00012191030249933228)
# (413, 0.00011635634672125767)
# (414, 0.00011105737582011691)
# (415, 0.00010599854381373891)
# (416, 0.00010117066885716625)
# (417, 9.6562918547768678e-05)
# (418, 9.2165372398158042e-05)
# (419, 8.7968645818270588e-05)
# (420, 8.3963663088416541e-05)
# (421, 8.0142047713388327e-05)
# (422, 7.6494174719423476e-05)
# (423, 7.3012984202279623e-05)
# (424, 6.9690428159783092e-05)
# (425, 6.6519321697601139e-05)
# (426, 6.3493003158399821e-05)
# (427, 6.0605182002642117e-05)
# (428, 5.7848478483356031e-05)
# (429, 5.5217452229927507e-05)
# (430, 5.2706260696712237e-05)
# (431, 5.0309562598586664e-05)
# (432, 4.802211838137928e-05)
# (433, 4.5839333564368109e-05)
# (434, 4.3755706269702638e-05)
# (435, 4.1766879918824767e-05)
# (436, 3.9868682292496053e-05)
# (437, 3.8057101968859536e-05)
# (438, 3.6327912184851227e-05)
# (439, 3.467770401785212e-05)
# (440, 3.310244660226382e-05)
# (441, 3.1598925197399892e-05)
# (442, 3.0163771126311062e-05)
# (443, 2.8793930180281978e-05)
# (444, 2.748654978023746e-05)
# (445, 2.6238919378372124e-05)
# (446, 2.5047802442066468e-05)
# (447, 2.3910840111142118e-05)
# (448, 2.2825593604301583e-05)
# (449, 2.1789679894938856e-05)
# (450, 2.0800866897326802e-05)
# (451, 1.9857159909865487e-05)
# (452, 1.8956331349519511e-05)
# (453, 1.8096371288203667e-05)
# (454, 1.7275559150023164e-05)
# (455, 1.6492015758984386e-05)
# (456, 1.5744113314974324e-05)
# (457, 1.5030195866478129e-05)
# (458, 1.4348796420435621e-05)
# (459, 1.3698263690031023e-05)
# (460, 1.3077320210198535e-05)
# (461, 1.2484578342393791e-05)
# (462, 1.191874137876011e-05)
# (463, 1.1378620492149237e-05)
# (464, 1.0863088930804301e-05)
# (465, 1.0370932030405874e-05)
# (466, 9.901085330467524e-06)
# (467, 9.4526173339742963e-06)
# (468, 9.0244976866351036e-06)
# (469, 8.6157886077617524e-06)
# (470, 8.2256101408314691e-06)
# (471, 7.8532074896661931e-06)
# (472, 7.4976276164096347e-06)
# (473, 7.1581956921483785e-06)
# (474, 6.8341771076373912e-06)
# (475, 6.5248358100883259e-06)
# (476, 6.2295253356076372e-06)
# (477, 5.9476185672503259e-06)
# (478, 5.6785249694871881e-06)
# (479, 5.4215879936014178e-06)
# (480, 5.1763096730806678e-06)
# (481, 4.9421523367869764e-06)
# (482, 4.718606937451284e-06)
# (483, 4.505265384781485e-06)
# (484, 4.3015714176171097e-06)
# (485, 4.1070798954618774e-06)
# (486, 3.9213737912396245e-06)
# (487, 3.7440876789000359e-06)
# (488, 3.5748256709350229e-06)
# (489, 3.4132334689009903e-06)
# (490, 3.2589567793059691e-06)
# (491, 3.1116755977112016e-06)
# (492, 2.9710911178465358e-06)
# (493, 2.8368429177792621e-06)
# (494, 2.7086730627735112e-06)
# (495, 2.5863005435139145e-06)
# (496, 2.4694681220014235e-06)
# (497, 2.3579213856520899e-06)
# (498, 2.2514254224880424e-06)
# (499, 2.1497651117357484e-06)

# %% [markdown]
# # Первая и основная составляющая типичного современного фреймворка для машинного обучения - Tensor

# %% [markdown]
# В интерфейсе базовых операций тензор ничем не отличается от np.array, но при этом тензоры можно эффективно использовать при обучении на gpu.

# %%
import torch

# %%
# Создаем неинициализированный тензор
x = torch.Tensor(5, 3)

# %%
x
# Out:
# 1.00000e-08 *
#  -0.0000  0.0000  6.0670
#   0.0000  0.0902  0.0000
#  -0.0000  0.0000 -0.0000
#   0.0000  0.0000  0.0000
#   0.0000  0.0000  0.0000
# [torch.FloatTensor of size 5x3]

# %%
# инициализируем тензор нормальным распределением
x = torch.randn(5, 3)

# %%
x
# Out:
#  1.4312 -0.4596  0.6051
# -1.2414  0.2560  1.3663
# -0.8991  0.6741 -0.5378
# -1.2244  1.1514 -1.9203
#  0.7451  1.3182 -0.6524
# [torch.FloatTensor of size 5x3]

# %%
x.size()
# Out:
# torch.Size([5, 3])

# %%
y = torch.rand(5, 3)

# %%
y
# Out:
#  0.7304  0.9615  0.2586
#  0.3227  0.7867  0.0043
#  0.8287  0.2735  0.0115
#  0.2667  0.1086  0.5766
#  0.4664  0.3912  0.6080
# [torch.FloatTensor of size 5x3]

# %%
# Первый способ сложить 2 тензора
x + y
# Out:
#  1.1486  1.6697  0.5079
#  1.0996  1.0322  0.5710
#  1.7468  1.1038  0.0869
#  0.5584  0.1626  1.1488
#  1.3252  0.8794  0.7790
# [torch.FloatTensor of size 5x3]

# %%
# Второй способ сложить 2 тензора
x.add(y)
# Out:
#  1.1486  1.6697  0.5079
#  1.0996  1.0322  0.5710
#  1.7468  1.1038  0.0869
#  0.5584  0.1626  1.1488
#  1.3252  0.8794  0.7790
# [torch.FloatTensor of size 5x3]

# %%
# А еще можно так:
torch.add(x, y)
# Out:
#  1.1486  1.6697  0.5079
#  1.0996  1.0322  0.5710
#  1.7468  1.1038  0.0869
#  0.5584  0.1626  1.1488
#  1.3252  0.8794  0.7790
# [torch.FloatTensor of size 5x3]

# %%
# Сохраняем выход в тензор result
result = torch.Tensor(5, 3)
torch.add(x, y, out=result)
# Out:
#  1.1486  1.6697  0.5079
#  1.0996  1.0322  0.5710
#  1.7468  1.1038  0.0869
#  0.5584  0.1626  1.1488
#  1.3252  0.8794  0.7790
# [torch.FloatTensor of size 5x3]

# %%
# Перевод из numpy в torch
a = np.ones(5)
b = torch.from_numpy(a)
np.add(a, 1, out=a)
print(a)
print(b)
# Out:
# [ 2.  2.  2.  2.  2.]
#
#  2
#  2
#  2
#  2
#  2
# [torch.DoubleTensor of size 5]

# %%
a = torch.randn(5, 3) 
b = torch.randn(3, 4)

# %%
# Матричное умножение

torch.mm(a,b)
a.mm(b)
# Out:
#  0.3363 -0.0260 -0.7842 -0.2396
# -2.9455  0.2255  2.0970  2.0056
#  0.2697 -0.2736 -2.2391 -0.3547
#  3.4643 -0.0478  1.2616 -2.1739
# -0.5717  0.4305 -0.1199  0.5803
# [torch.FloatTensor of size 5x4]

# %%
# для python 3

a @ b
# Out:
#   File "<ipython-input-12-6c2aa174fbbf>", line 3
#     a @ b
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# # предостережение!

# %% [markdown]
# В Pytorch пока нет встроенной реализации broadcasting

# %%
W = torch.randn(100, 10)
x = torch.randn(1, 100)
b = torch.ones(10)

# %%
x.mm(W) + b
# Out:
# Columns 0 to 7
#   7.6287  -6.7664  -8.9270  18.7777  24.6697  12.1760   6.5281  -0.9651
#
# Columns 8 to 9
#  -4.7679   0.7349
# [torch.FloatTensor of size 1x10]

# %%
x = torch.randn(5, 100)
x.mm(W) + b
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-20-343405a772f9> in <module>()
#       1 x = torch.randn(5, 100)
# ----> 2 x.mm(W) + b
#
# /usr/local/lib/python3.5/site-packages/torch/tensor.py in __add__(self, other)
#     302     # TODO: add tests for operators
#     303     def __add__(self, other):
# --> 304         return self.add(other)
#     305     __radd__ = __add__
#     306
#
# RuntimeError: inconsistent tensor size at /Users/kuzmahrabrov/PlayGround/git/pytorch_tr/torch/lib/TH/generic/THTensorMath.c:601

# %%
# walk-through

x.mm(W) + b.repeat(x.size(0), 1)
# Out:
# Columns 0 to 7
#   7.6287  -6.7664  -8.9270  18.7777  24.6697  12.1760   6.5281  -0.9651
#
# Columns 8 to 9
#  -4.7679   0.7349
# [torch.FloatTensor of size 1x10]

# %% [markdown]
# Поменяем пару строчек в обучении на np и код уже можно запускать и на GPU

# %%
dtype = torch.FloatTensor
# dtype = torch.cuda.FloatTensor # GPU

N, D_in, H, D_out = 64, 1000, 100, 10

x = torch.randn(N, D_in).type(dtype)
y = torch.randn(N, D_out).type(dtype)

w1 = torch.randn(D_in, H).type(dtype)
w2 = torch.randn(H, D_out).type(dtype)

learning_rate = 1e-6
for t in range(500):

    h = x.mm(w1)
    h_relu = h.clamp(min=0)
    y_pred = h_relu.mm(w2)

    loss = (y_pred - y).pow(2).sum()
    print(t, loss)

    grad_y_pred = 2.0 * (y_pred - y)
    grad_w2 = h_relu.t().mm(grad_y_pred)
    grad_h_relu = grad_y_pred.mm(w2.t())
    grad_h = grad_h_relu.clone()
    grad_h[h < 0] = 0
    grad_w1 = x.t().mm(grad_h)

    w1 -= learning_rate * grad_w1
    w2 -= learning_rate * grad_w2
# Out:
# (0, 32809676.16619301)
# (1, 28693061.05315274)
# (2, 27519888.43800968)
# (3, 25039857.47220069)
# (4, 20054157.53912587)
# (5, 13773547.718563348)
# (6, 8429069.927183434)
# (7, 4877779.911807358)
# (8, 2874545.9275149256)
# (9, 1803808.6938624352)
# (10, 1229438.6448661834)
# (11, 902951.1126687311)
# (12, 702149.4485889704)
# (13, 567664.8116604462)
# (14, 470800.8592473045)
# (15, 397049.25353155425)
# (16, 338675.8176319734)
# (17, 291295.93393846485)
# (18, 252130.86828962527)
# (19, 219363.69066592155)
# (20, 191698.03767338302)
# (21, 168138.33823114506)
# (22, 147987.21340766735)
# (23, 130687.0741750876)
# (24, 115768.55118560394)
# (25, 102826.84706028295)
# (26, 91565.03858716623)
# (27, 81739.43105763849)
# (28, 73147.75508910605)
# (29, 65592.53232185107)
# (30, 58947.797676694376)
# (31, 53077.57720127303)
# (140, 31.085762265338417)
# (141, 29.537340858037453)
# (142, 28.07054987815838)
# (143, 26.68254044688641)
# (144, 25.367933312808717)
# (145, 24.122905344654274)
# (146, 22.94201786084236)
# (147, 21.82407389577459)
# (148, 20.764657774525237)
# (149, 19.76036151453826)
# (150, 18.807357265937867)
# (151, 17.903339128587138)
# (152, 17.04643610447363)
# (153, 16.232919494452574)
# (154, 15.461273084695335)
# (155, 14.72848895300686)
# (156, 14.03342852147172)
# (157, 13.372538308764646)
# (158, 12.745250373002932)
# (159, 12.149011319304797)
# (160, 11.583275028195551)
# (161, 11.045662514236621)
# (162, 10.534453461611424)
# (163, 10.048351488306665)
# (164, 9.585991806525598)
# (165, 9.146292726679704)
# (166, 8.728403963787613)
# (167, 8.330536093928337)
# (168, 7.951603613726945)
# (169, 7.591700235472438)
# (170, 7.249084534749045)
# (171, 6.922358592677455)
# (172, 6.61165095118416)
# (173, 6.315635795735915)
# (174, 6.033803479293263)
# (175, 5.765063831772821)
# (176, 5.509170684759983)
# (177, 5.265497909697103)
# (178, 5.03308308796646)
# (179, 4.811657166956284)
# (180, 4.600713196708206)
# (181, 4.399302364097011)
# (182, 4.207260829899152)
# (183, 4.024073319046863)
# (184, 3.8491066957507485)
# (185, 3.6825946229025206)
# (186, 3.5236254492011305)
# (187, 3.371812443336464)
# (188, 3.226851395303343)
# (189, 3.088288243998864)
# (190, 2.9562110215527087)
# (191, 2.8300446891735156)
# (192, 2.709615971685338)
# (193, 2.594295552681146)
# (194, 2.4842085719373337)
# (195, 2.3794075358961138)
# (196, 2.2789119561689564)
# (197, 2.1829819816985783)
# (198, 2.0911806797614503)
# (199, 2.003453384800773)
# (200, 1.9197318099914433)
# (201, 1.8396622703036574)
# (202, 1.7630884371310325)
# (203, 1.6897169358817523)
# (204, 1.619602722048154)
# (205, 1.5525086952703964)
# (206, 1.4884285911350945)
# (207, 1.427151704095508)
# (208, 1.368350006398452)
# (209, 1.3120652638042407)
# (210, 1.2583282699118854)
# (211, 1.2068855428192524)
# (212, 1.157529589830519)
# (213, 1.1103124889097344)
# (214, 1.0650498286346313)
# (215, 1.0217965879932542)
# (216, 0.9802862708465021)
# (217, 0.9406000366624445)
# (218, 0.9025366036353519)
# (219, 0.8660878090617494)
# (220, 0.8314105158140288)
# (221, 0.7984211037415152)
# (222, 0.7667247934600292)
# (223, 0.7364412813821817)
# (224, 0.7073009805695358)
# (225, 0.679376793482712)
# (226, 0.6526163564131446)
# (227, 0.6269412792166129)
# (228, 0.6023459209956101)
# (229, 0.5787787445492021)
# (230, 0.5560584307858054)
# (231, 0.5343460441928558)
# (232, 0.5135315568619152)
# (233, 0.49349525364268865)
# (234, 0.47425634588192)
# (235, 0.45579651050850245)
# (236, 0.4380553124444484)
# (237, 0.42108005273461746)
# (238, 0.4048201594022558)
# (239, 0.38916542661528997)
# (240, 0.37421398350349744)
# (241, 0.3597338317345051)
# (242, 0.34587820821152904)
# (243, 0.3325473222775308)
# (244, 0.3197899265537305)
# (245, 0.3074800465305252)
# (246, 0.29570692288613376)
# (247, 0.2843652943251431)
# (248, 0.27349049098959277)
# (249, 0.2630426835535413)
# (250, 0.2530042753738444)
# (251, 0.24335443160846015)
# (252, 0.23404707820010096)
# (253, 0.22510799390945824)
# (254, 0.21659234253762016)
# (255, 0.20836491592349304)
# (256, 0.20044429957344523)
# (257, 0.19285076517240363)
# (258, 0.1855271085239787)
# (259, 0.17849060471405043)
# (260, 0.17173998698614668)
# (261, 0.165263701652842)
# (262, 0.15904066481395862)
# (263, 0.15303524204204244)
# (264, 0.14725501066302304)
# (265, 0.14172574049381237)
# (266, 0.13636904086498713)
# (267, 0.1312610208945335)
# (268, 0.12631035230152676)
# (269, 0.12157580362726428)
# (270, 0.11699214590678242)
# (271, 0.11263072032000743)
# (272, 0.10840797662237645)
# (273, 0.10433872091449459)
# (274, 0.1004577780741629)
# (275, 0.09671154312845065)
# (276, 0.09308191946745037)
# (277, 0.08961858822924729)
# (278, 0.08626987123377194)
# (279, 0.08307535033379665)
# (280, 0.07998382990565123)
# (281, 0.07701265991330519)
# (282, 0.07413080313768905)
# (283, 0.07137653631033469)
# (284, 0.06875672172021594)
# (285, 0.06619369418359722)
# (286, 0.06374529781614702)
# (287, 0.06137418272864004)
# (288, 0.05911932455865099)
# (289, 0.05692248136673328)
# (290, 0.054816972085238724)
# (291, 0.052804739760986985)
# (292, 0.050852803145255976)
# (293, 0.04899325164861956)
# (294, 0.047181560257019806)
# (295, 0.04544280143735846)
# (296, 0.043775107462772134)
# (297, 0.04217273710189495)
# (298, 0.04062554901212412)
# (299, 0.039134663352575316)
# (300, 0.03768283256014371)
# (301, 0.0363012515095118)
# (302, 0.03497722074911458)
# (303, 0.03369324894567938)
# (304, 0.03245500041077909)
# (305, 0.031274276344199214)
# (306, 0.030142894150251953)
# (307, 0.029053502424669753)
# (308, 0.027996544762624254)
# (309, 0.026973195184034404)
# (310, 0.0259961220702547)
# (311, 0.02504690916939234)
# (312, 0.02414138463151705)
# (313, 0.023271603411323838)
# (314, 0.0224280422523635)
# (315, 0.0216035144169876)
# (316, 0.020826824507388708)
# (317, 0.020077864201792084)
# (318, 0.01935279442874205)
# (319, 0.01865545180930539)
# (320, 0.017985274092033432)
# (321, 0.017342762039996185)
# (322, 0.01670995375909201)
# (323, 0.016116816770862963)
# (324, 0.015541330121815022)
# (325, 0.014989088212735036)
# (326, 0.014443569732505379)
# (327, 0.013928841464994512)
# (328, 0.013433560061322791)
# (329, 0.01294774297623591)
# (330, 0.012495135980056207)
# (331, 0.012043470265795664)
# (332, 0.01161783302702668)
# (333, 0.011203206474651534)
# (334, 0.010807042036309444)
# (335, 0.010425557532490859)
# (336, 0.010061901931455064)
# (337, 0.009706995807136062)
# (338, 0.009364714821413215)
# (339, 0.009035943479980185)
# (340, 0.00871500133356809)
# (341, 0.008413507293285175)
# (342, 0.008119127425277515)
# (343, 0.007837244700124438)
# (344, 0.007557027270434016)
# (345, 0.007299915128715084)
# (346, 0.007050616261447623)
# (347, 0.006803374362092888)
# (348, 0.0065686687642112045)
# (349, 0.0063445254645136395)
# (350, 0.006126023063615926)
# (351, 0.005919504683132626)
# (352, 0.0057182865662966376)
# (353, 0.005524490319236519)
# (354, 0.005337977742618377)
# (355, 0.005154055690611226)
# (356, 0.004978730667196951)
# (357, 0.004811856183641869)
# (358, 0.004646145946048341)
# (359, 0.0044909430020884655)
# (360, 0.004341715873306316)
# (361, 0.004196342767113503)
# (362, 0.00405718748497659)
# (363, 0.003920698880826055)
# (364, 0.003791382192306656)
# (365, 0.0036684281875870584)
# (366, 0.003547637486883224)
# (367, 0.003429349611495991)
# (368, 0.003317730753099435)
# (369, 0.0032107442063334934)
# (370, 0.0031052390332965696)
# (371, 0.003004931556291404)
# (372, 0.0029078344789834204)
# (373, 0.002813855080116893)
# (374, 0.002723973844840702)
# (375, 0.0026362214962041275)
# (376, 0.002552099009885525)
# (377, 0.002474590072364169)
# (378, 0.002395178292514788)
# (379, 0.002319556640800524)
# (380, 0.002248193839139101)
# (381, 0.0021756287595936646)
# (382, 0.0021108894863424155)
# (383, 0.0020430807159099174)
# (384, 0.001982813756365956)
# (385, 0.0019214303913300257)
# (386, 0.0018630848337495044)
# (387, 0.0018057706603704649)
# (388, 0.0017501225379983332)
# (389, 0.001696541346589031)
# (390, 0.0016462053315745018)
# (391, 0.001598332948983039)
# (392, 0.0015514511957516186)
# (393, 0.0015042333714511726)
# (394, 0.0014596417924807037)
# (395, 0.0014172366750307974)
# (396, 0.0013757729335622249)
# (397, 0.0013360111049135932)
# (398, 0.0012978493089307874)
# (399, 0.001259299604392708)
# (400, 0.0012235490321901646)
# (401, 0.0011890304341953262)
# (402, 0.0011539951119597935)
# (403, 0.0011210437783666961)
# (404, 0.0010887630881971228)
# (405, 0.0010587560885150088)
# (406, 0.0010293421102268302)
# (407, 0.001001146095182412)
# (408, 0.0009735789550993634)
# (409, 0.000946357024414507)
# (410, 0.0009179999161068736)
# (411, 0.0008955549175935773)
# (412, 0.000870055377570747)
# (413, 0.0008468636771574731)
# (414, 0.0008238486766892206)
# (415, 0.0008031761853457033)
# (416, 0.000782136305056789)
# (417, 0.0007623687732250667)
# (418, 0.0007426001877256505)
# (419, 0.0007225995343572711)
# (420, 0.0007050805436445429)
# (421, 0.0006855852075567381)
# (422, 0.0006677601541523193)
# (423, 0.0006499218643324367)
# (424, 0.0006335708925050421)
# (425, 0.0006164811869607822)
# (426, 0.0006018995067321176)
# (427, 0.0005868735600792485)
# (428, 0.0005719261119170316)
# (429, 0.0005573614335258048)
# (430, 0.0005441834918666344)
# (431, 0.0005304385542524992)
# (432, 0.0005172358956146428)
# (433, 0.0005046418683823384)
# (434, 0.0004926152659936456)
# (435, 0.000481018811778533)
# (436, 0.00047068671014566243)
# (437, 0.00045898816342487825)
# (438, 0.0004493317965047483)
# (439, 0.00043760939298903567)
# (440, 0.0004276423027292364)
# (441, 0.00041743119833459463)
# (442, 0.00040817051330072074)
# (443, 0.00039883353749700645)
# (444, 0.00038922755759772387)
# (445, 0.000380915884114319)
# (446, 0.0003722473532842274)
# (447, 0.00036357882693915933)
# (448, 0.0003559977591265362)
# (449, 0.0003479496545306694)
# (450, 0.00034071391598801404)
# (451, 0.0003328539452523739)
# (452, 0.0003254997871625087)
# (453, 0.00031854782197973663)
# (454, 0.0003118359804741913)
# (455, 0.00030594224521983404)
# (456, 0.00029899008670862537)
# (457, 0.00029240885984470333)
# (458, 0.00028687322301777785)
# (459, 0.00028050591386047374)
# (460, 0.0002751140629864181)
# (461, 0.0002696374861366757)
# (462, 0.00026352866250421714)
# (463, 0.00025806356354730886)
# (464, 0.0002535463427200818)
# (465, 0.00024886867791443223)
# (466, 0.00024321193649669282)
# (467, 0.0002389005248348841)
# (468, 0.00023421670172406317)
# (469, 0.00022896587681517366)
# (470, 0.00022393070290826697)
# (471, 0.00022000404665287882)
# (472, 0.00021591549421341033)
# (473, 0.0002116914364391001)
# (474, 0.00020758158946660582)
# (475, 0.00020368171767388976)
# (476, 0.00019975507049575791)
# (477, 0.0001960583587985766)
# (478, 0.00019219603306417352)
# (479, 0.00018810122277763963)
# (480, 0.0001846860867109057)
# (481, 0.0001816695875987845)
# (482, 0.0001786389330696997)
# (483, 0.00017521899356010007)
# (484, 0.00017164523563344136)
# (485, 0.00016866401357693364)
# (486, 0.00016575986087477568)
# (487, 0.00016266268701948562)
# (488, 0.00015981643016531669)
# (489, 0.000157301732484752)
# (490, 0.000154559697111048)
# (491, 0.00015166881315098468)
# (492, 0.00014936872717125071)
# (493, 0.00014670416467315456)
# (494, 0.00014423562272460055)
# (495, 0.00014202128866093455)
# (496, 0.00013944841913428319)
# (497, 0.00013698772649361687)
# (498, 0.00013471114185159908)
# (499, 0.0001327320678903149)

# %% [markdown]
# # Но самое важное в фреймворках - графы вычисления и автоматическое дифференцирование

# %%
# Variable - обертка над тензором, содержащая значения градиента и еще немного полезной информации
from torch.autograd import Variable
x = Variable(torch.ones(2, 2), requires_grad = True)
x
# Out:
# Variable containing:
#  1  1
#  1  1
# [torch.FloatTensor of size 2x2]

# %%
x.data
# Out:
#  1  1
#  1  1
# [torch.FloatTensor of size 2x2]

# %%
x.grad
# Out:
# Variable containing:
#  0  0
#  0  0
# [torch.FloatTensor of size 2x2]

# %%
# операция, которая породила переменную.
x.creator is None
# Out:
# True

# %%
y = x + 2
y
# Out:
# Variable containing:
#  3  3
#  3  3
# [torch.FloatTensor of size 2x2]

# %%
y.creator.previous_functions
# Out:
# ((Variable containing:
#    1  1
#    1  1
#   [torch.FloatTensor of size 2x2], 0),)

# %%
y.grad
# Out:
# Variable containing:
#  0  0
#  0  0
# [torch.FloatTensor of size 2x2]

# %%
z = y * y * 2
z
# Out:
# Variable containing:
#  18  18
#  18  18
# [torch.FloatTensor of size 2x2]

# %%
z.creator.previous_functions
# Out:
# ((<torch.autograd._functions.basic_ops.Mul at 0x7f88a80c1230>, 0),)

# %%
out = z.mean()
out
# Out:
# Variable containing:
#  18
# [torch.FloatTensor of size 1]

# %%
out.creator.previous_functions
# Out:
# ((<torch.autograd._functions.basic_ops.MulConstant at 0x7f88a80c1050>, 0),)

# %%
# Запускаем бэкпроп
out.backward()

# %%
# dout/dz = 1/n = 1/4
# dout/dy = dout/dz * dz/dy = y
# dout/dx = y = (3 3 3 3)

# %%
x.grad
# Out:
# Variable containing:
#  3  3
#  3  3
# [torch.FloatTensor of size 2x2]

# %%
y.grad # used
# Out:
# Variable containing:
#  0  0
#  0  0
# [torch.FloatTensor of size 2x2]

# %%
z.grad # used
# Out:
# Variable containing:
#  0  0
#  0  0
# [torch.FloatTensor of size 2x2]

# %% [markdown]
# # Что произошло?

# %% [markdown]
# autograd строит ациклический граф высчисления из переменных и операций(функций)
# out.backward проходит по всему графу начиная от вершины out и считает градиенты вершин

# %%
class MyReLU(torch.autograd.Function):

    def forward(self, input):
        # forward pass
        self.save_for_backward(input)
        return input.clamp(min=0) # max(0, x)

    def backward(self, grad_output):
    # backward pass
        print(self.saved_tensors)
        print(grad_output.clone)
        input, = self.saved_tensors
        grad_input = grad_output.clone()
        grad_input[input < 0] = 0
        return grad_input

# %% [markdown]
# Если мы хотим сохранить значения переменных в графе, то используем retain_variables = True.
# Это может быть нужно, если мы хотим несколько раз подряд сделать backprop

# %%
x = Variable(torch.ones(2, 2), requires_grad = True)
y = x + 2

# %%
y.backward(torch.ones(2, 2)) # setting up gradient is necessary because it's not a scalar
x.grad
# Out:
# Variable containing:
#  1  1
#  1  1
# [torch.FloatTensor of size 2x2]

# %%
gradient = torch.randn(2, 2)

y.backward(gradient)

x.grad
# Out:
# Variable containing:
#  1.5334  0.9173
#  2.9637  0.3069
# [torch.FloatTensor of size 2x2]

# %%
gradient
# Out:
#  0.5334 -0.0827
#  1.9637 -0.6931
# [torch.FloatTensor of size 2x2]

# %%
x = Variable(torch.ones(2, 2), requires_grad = True)
y = x + 2
y.backward(torch.ones(2, 2), retain_variables=True)
x.grad
# Out:
# Variable containing:
#  1  1
#  1  1
# [torch.FloatTensor of size 2x2]

# %%
gradient = torch.randn(2, 2)

y.backward(gradient)

x.grad
# Out:
# Variable containing:
# -5.2829  4.0769
#  2.3827  2.7675
# [torch.FloatTensor of size 2x2]

# %% [markdown]
# # Снова вернемся к исходной двухслойной сети

# %%
import torch
from torch.autograd import Variable

dtype = torch.FloatTensor
# dtype = torch.cuda.FloatTensor # GPU

N, D_in, H, D_out = 64, 1000, 100, 10


x = Variable(torch.randn(N, D_in).type(dtype), requires_grad=False) # don't optimize f(x), f(y)
y = Variable(torch.randn(N, D_out).type(dtype), requires_grad=False)


w1 = Variable(torch.randn(D_in, H).type(dtype), requires_grad=True)
w2 = Variable(torch.randn(H, D_out).type(dtype), requires_grad=True)

learning_rate = 1e-6
for t in range(500):
    y_pred = x.mm(w1).clamp(min=0).mm(w2)

    loss = (y_pred - y).pow(2).sum()
    print(t, loss.data[0])
    
    # Обнуляем градиенты
    w1.grad.data.zero_()
    w2.grad.data.zero_()

    loss.backward()

    w1.data -= learning_rate * w1.grad.data
    w2.data -= learning_rate * w2.grad.data
# Out:
# (0, 23188858.0)
# (1, 19625572.0)
# (2, 20631708.0)
# (3, 23688930.0)
# (4, 26474370.0)
# (5, 26236608.0)
# (6, 21936760.0)
# (7, 15079663.0)
# (8, 8890982.0)
# (9, 4777666.0)
# (10, 2569942.5)
# (11, 1472381.625)
# (12, 935577.375)
# (13, 659171.9375)
# (14, 504209.78125)
# (15, 407519.9375)
# (16, 340670.59375)
# (17, 290597.625)
# (18, 250954.078125)
# (19, 218450.59375)
# (20, 191223.796875)
# (21, 168142.296875)
# (22, 148366.6875)
# (23, 131375.953125)
# (24, 116686.8515625)
# (25, 103909.3515625)
# (137, 48.38801956176758)
# (138, 45.98347473144531)
# (139, 43.70307159423828)
# (140, 41.540042877197266)
# (141, 39.4881706237793)
# (142, 37.54238510131836)
# (143, 35.69459533691406)
# (144, 33.94180679321289)
# (145, 32.27799987792969)
# (146, 30.698381423950195)
# (147, 29.19831657409668)
# (148, 27.775253295898438)
# (149, 26.423038482666016)
# (150, 25.13890266418457)
# (151, 23.919113159179688)
# (152, 22.760204315185547)
# (153, 21.65983772277832)
# (154, 20.614112854003906)
# (155, 19.620424270629883)
# (156, 18.67593765258789)
# (157, 17.778573989868164)
# (158, 16.924774169921875)
# (159, 16.113515853881836)
# (160, 15.343306541442871)
# (161, 14.609735488891602)
# (162, 13.91306209564209)
# (163, 13.249971389770508)
# (164, 12.619084358215332)
# (165, 12.019474983215332)
# (166, 11.448443412780762)
# (167, 10.906268119812012)
# (168, 10.389982223510742)
# (169, 9.898810386657715)
# (170, 9.431479454040527)
# (171, 8.986478805541992)
# (172, 8.563188552856445)
# (173, 8.160298347473145)
# (174, 7.776427268981934)
# (175, 7.410977363586426)
# (176, 7.063995838165283)
# (177, 6.732864856719971)
# (178, 6.418074607849121)
# (179, 6.118053913116455)
# (180, 5.832311153411865)
# (181, 5.560168743133545)
# (182, 5.301097869873047)
# (183, 5.054283618927002)
# (184, 4.819353103637695)
# (185, 4.595443248748779)
# (186, 4.381859302520752)
# (187, 4.178810119628906)
# (188, 3.9851815700531006)
# (189, 3.801020383834839)
# (190, 3.6251842975616455)
# (191, 3.4576025009155273)
# (192, 3.298175811767578)
# (193, 3.1459295749664307)
# (194, 3.0011017322540283)
# (195, 2.8629050254821777)
# (196, 2.7312326431274414)
# (197, 2.605674982070923)
# (198, 2.4861152172088623)
# (199, 2.3719429969787598)
# (200, 2.2632813453674316)
# (201, 2.1594655513763428)
# (202, 2.06052827835083)
# (203, 1.9663360118865967)
# (204, 1.8764854669570923)
# (205, 1.7907296419143677)
# (206, 1.7090022563934326)
# (207, 1.6310781240463257)
# (208, 1.5567740201950073)
# (209, 1.4859989881515503)
# (210, 1.4181967973709106)
# (211, 1.3537706136703491)
# (212, 1.2922375202178955)
# (213, 1.2334840297698975)
# (214, 1.1776460409164429)
# (215, 1.124233365058899)
# (216, 1.0732579231262207)
# (217, 1.0246473550796509)
# (218, 0.9783232808113098)
# (219, 0.9341025352478027)
# (220, 0.8919381499290466)
# (221, 0.8515360355377197)
# (222, 0.8130987286567688)
# (223, 0.7764413952827454)
# (224, 0.7413899302482605)
# (225, 0.7080117464065552)
# (226, 0.6760815382003784)
# (227, 0.6457245349884033)
# (228, 0.6165984869003296)
# (229, 0.5889058709144592)
# (230, 0.562463104724884)
# (231, 0.5372176766395569)
# (232, 0.5130490660667419)
# (233, 0.49004021286964417)
# (234, 0.4680499732494354)
# (235, 0.44710806012153625)
# (236, 0.4271005690097809)
# (237, 0.4079192578792572)
# (238, 0.38969290256500244)
# (239, 0.37226206064224243)
# (240, 0.35558760166168213)
# (241, 0.3397076725959778)
# (242, 0.32457515597343445)
# (243, 0.310103178024292)
# (244, 0.29627329111099243)
# (245, 0.283075213432312)
# (246, 0.2704867124557495)
# (247, 0.25836503505706787)
# (248, 0.24689346551895142)
# (249, 0.23591874539852142)
# (250, 0.225428968667984)
# (251, 0.2154131978750229)
# (252, 0.20583075284957886)
# (253, 0.19665676355361938)
# (254, 0.18794260919094086)
# (255, 0.1796298325061798)
# (256, 0.17164792120456696)
# (257, 0.16403630375862122)
# (258, 0.15677881240844727)
# (259, 0.14983701705932617)
# (260, 0.14318706095218658)
# (261, 0.13685362040996552)
# (262, 0.13078895211219788)
# (263, 0.12502893805503845)
# (264, 0.1195087879896164)
# (265, 0.11423718184232712)
# (266, 0.10917028039693832)
# (267, 0.10437457263469696)
# (268, 0.09975245594978333)
# (269, 0.09538169205188751)
# (270, 0.09114806354045868)
# (271, 0.08714339882135391)
# (272, 0.08329874277114868)
# (273, 0.07962500303983688)
# (274, 0.07614905387163162)
# (275, 0.0727778747677803)
# (276, 0.06958917528390884)
# (277, 0.06651224941015244)
# (278, 0.0636092871427536)
# (279, 0.06081119552254677)
# (280, 0.058159735053777695)
# (281, 0.05560692772269249)
# (282, 0.05318065360188484)
# (283, 0.050846751779317856)
# (284, 0.04860793426632881)
# (285, 0.04647824913263321)
# (286, 0.04445230960845947)
# (287, 0.042498115450143814)
# (288, 0.04064234346151352)
# (289, 0.03887195140123367)
# (290, 0.03717126324772835)
# (291, 0.035543158650398254)
# (292, 0.03400450944900513)
# (293, 0.03253106027841568)
# (294, 0.03110848367214203)
# (295, 0.029754480347037315)
# (296, 0.02845785953104496)
# (297, 0.027210749685764313)
# (298, 0.026039985939860344)
# (299, 0.024908296763896942)
# (300, 0.02383469231426716)
# (301, 0.02279765158891678)
# (302, 0.021815991029143333)
# (303, 0.020873093977570534)
# (304, 0.019964495673775673)
# (305, 0.019114699214696884)
# (306, 0.01828446052968502)
# (307, 0.01750083453953266)
# (308, 0.016749761998653412)
# (309, 0.016034811735153198)
# (310, 0.015347040258347988)
# (311, 0.014686779119074345)
# (312, 0.014056502841413021)
# (313, 0.013459911569952965)
# (314, 0.012886802665889263)
# (315, 0.012343892827630043)
# (316, 0.011814805679023266)
# (317, 0.011311162263154984)
# (318, 0.010827286168932915)
# (319, 0.01036766916513443)
# (320, 0.009930543601512909)
# (321, 0.009510825388133526)
# (322, 0.009114446118474007)
# (323, 0.008726589381694794)
# (324, 0.008358442224562168)
# (325, 0.008012300357222557)
# (326, 0.007675941102206707)
# (327, 0.007356137968599796)
# (328, 0.007051323540508747)
# (329, 0.006755202542990446)
# (330, 0.006473582237958908)
# (331, 0.006203153170645237)
# (332, 0.005947007331997156)
# (333, 0.005702694412320852)
# (334, 0.005466473288834095)
# (335, 0.005243213381618261)
# (336, 0.005031471140682697)
# (337, 0.004828243982046843)
# (338, 0.004631570540368557)
# (339, 0.00444358866661787)
# (340, 0.004261084832251072)
# (341, 0.0040908511728048325)
# (342, 0.003928612917661667)
# (343, 0.0037680596578866243)
# (344, 0.0036180738825351)
# (345, 0.003479474224150181)
# (346, 0.0033404070418328047)
# (347, 0.0032088845036923885)
# (348, 0.0030845431610941887)
# (349, 0.002965502208098769)
# (350, 0.002850022166967392)
# (351, 0.0027383912820369005)
# (352, 0.002631371608003974)
# (353, 0.002534163184463978)
# (354, 0.002435703296214342)
# (355, 0.002344115637242794)
# (356, 0.0022549389395862818)
# (357, 0.002167817670851946)
# (358, 0.002087366534397006)
# (359, 0.002009847667068243)
# (360, 0.0019342838786542416)
# (361, 0.0018638635519891977)
# (362, 0.0017968693282455206)
# (363, 0.0017310561379417777)
# (364, 0.0016657846281304955)
# (365, 0.0016079910565167665)
# (366, 0.001550353947095573)
# (367, 0.0014930712059140205)
# (368, 0.0014415309997275472)
# (369, 0.001389806275255978)
# (370, 0.0013416351284831762)
# (371, 0.0012945350026711822)
# (372, 0.0012484071776270866)
# (373, 0.0012057267595082521)
# (374, 0.0011626619379967451)
# (375, 0.0011224205372855067)
# (376, 0.0010849074460566044)
# (377, 0.0010500496719032526)
# (378, 0.0010137305362150073)
# (379, 0.0009809572948142886)
# (380, 0.0009489417425356805)
# (381, 0.0009174461010843515)
# (382, 0.0008865607669577003)
# (383, 0.0008579988498240709)
# (384, 0.0008300190092995763)
# (385, 0.0008030906901694834)
# (386, 0.0007783548790030181)
# (387, 0.0007533761090599)
# (388, 0.0007293568924069405)
# (389, 0.0007074426976032555)
# (390, 0.0006864478345960379)
# (391, 0.0006659890059381723)
# (392, 0.0006452933885157108)
# (393, 0.0006263150135055184)
# (394, 0.0006065794732421637)
# (395, 0.0005898399977013469)
# (396, 0.0005731723504140973)
# (397, 0.0005549738416448236)
# (398, 0.0005394414183683693)
# (399, 0.0005242144106887281)
# (400, 0.0005080564296804368)
# (401, 0.0004934197058901191)
# (402, 0.00047886327956803143)
# (403, 0.0004649494949262589)
# (404, 0.0004522581002674997)
# (405, 0.00043928000377491117)
# (406, 0.0004261875874362886)
# (407, 0.000414187932619825)
# (408, 0.0004027046379633248)
# (409, 0.00039200461469590664)
# (410, 0.00038206722820177674)
# (411, 0.0003720195672940463)
# (412, 0.00036259161424823105)
# (413, 0.00035218457924202085)
# (414, 0.0003425910254009068)
# (415, 0.000333998556016013)
# (416, 0.00032539392122998834)
# (417, 0.00031720654806122184)
# (418, 0.0003086976066697389)
# (419, 0.0003018793067894876)
# (420, 0.0002944000589195639)
# (421, 0.00028716964880004525)
# (422, 0.0002796640037558973)
# (423, 0.00027341884560883045)
# (424, 0.0002661323524080217)
# (425, 0.00025915843434631824)
# (426, 0.00025337658007629216)
# (427, 0.00024717170163057745)
# (428, 0.000240575143834576)
# (429, 0.000234611114137806)
# (430, 0.00022928295948076993)
# (431, 0.0002238388842670247)
# (432, 0.0002189703081967309)
# (433, 0.00021400900732260197)
# (434, 0.00020896311616525054)
# (435, 0.00020385850802995265)
# (436, 0.000198693698621355)
# (437, 0.00019453746790532023)
# (438, 0.00019062230421695858)
# (439, 0.00018599852046463639)
# (440, 0.00018263875972479582)
# (441, 0.0001787162764230743)
# (442, 0.00017430730804335326)
# (443, 0.00017036419012583792)
# (444, 0.00016721559222787619)
# (445, 0.00016332906670868397)
# (446, 0.00016032476560212672)
# (447, 0.00015641484060324728)
# (448, 0.00015373624046333134)
# (449, 0.0001508791174273938)
# (450, 0.0001475929602747783)
# (451, 0.00014403878594748676)
# (452, 0.00014135574747342616)
# (453, 0.00013878078607376665)
# (454, 0.0001365050848107785)
# (455, 0.0001331191451754421)
# (456, 0.00013070771819911897)
# (457, 0.00012801967386621982)
# (458, 0.00012565315410029143)
# (459, 0.00012313057959545404)
# (460, 0.00012041169975418597)
# (461, 0.00011806344264186919)
# (462, 0.00011592981172725558)
# (463, 0.00011397086927900091)
# (464, 0.00011172061931574717)
# (465, 0.00010947965347440913)
# (466, 0.00010772654786705971)
# (467, 0.00010558805661275983)
# (468, 0.00010369512165198103)
# (469, 0.00010183153062826023)
# (470, 0.00010002219642046839)
# (471, 9.833664807956666e-05)
# (472, 9.684274846222252e-05)
# (473, 9.532199328532442e-05)
# (474, 9.374359069624916e-05)
# (475, 9.179520566249266e-05)
# (476, 8.985041495179757e-05)
# (477, 8.828086720313877e-05)
# (478, 8.646624337416142e-05)
# (479, 8.4961429820396e-05)
# (480, 8.363549568457529e-05)
# (481, 8.190526568796486e-05)
# (482, 8.088842878350988e-05)
# (483, 7.938592170830816e-05)
# (484, 7.829766400391236e-05)
# (485, 7.691668724874035e-05)
# (486, 7.521323277615011e-05)
# (487, 7.428674143739045e-05)
# (488, 7.311302033485845e-05)
# (489, 7.186702714534476e-05)
# (490, 7.07646322553046e-05)
# (491, 6.96471834089607e-05)
# (492, 6.853839295217767e-05)
# (493, 6.746980943717062e-05)
# (494, 6.636231410084292e-05)
# (495, 6.540197500726208e-05)
# (496, 6.447799387387931e-05)
# (497, 6.358521932270378e-05)
# (498, 6.261206726776436e-05)
# (499, 6.167950778035447e-05)

# %% [markdown]
# # Наконец, во многих фреймворках базовые слои нейронных сетей уже реализованы. Прямо как в первом домашнем задании!

# %%
from torch.autograd import Variable

N, D_in, D_out = 64, 1000, 10

x = Variable(torch.randn(N, D_in))
y = Variable(torch.randn(N, D_out), requires_grad=False)

model = torch.nn.Sequential(
          torch.nn.Linear(D_in, D_out)
        )

loss_fn = torch.nn.MSELoss(size_average=False)

learning_rate = 1e-4
for t in range(500):
    y_pred = model(x)

    loss = loss_fn(y_pred, y)
    print(t, loss.data[0])

    model.zero_grad()

    loss.backward()

    for param in model.parameters():
        param.data -= learning_rate * param.grad.data
# Out:
# (0, 934.1334228515625)
# (1, 597.23095703125)
# (2, 388.3411560058594)
# (3, 256.59918212890625)
# (4, 172.109375)
# (5, 117.04100799560547)
# (6, 80.5948715209961)
# (7, 56.126380920410156)
# (8, 39.4816780090332)
# (9, 28.022871017456055)
# (10, 20.04847526550293)
# (11, 14.444928169250488)
# (12, 10.473118782043457)
# (13, 7.636033535003662)
# (14, 5.5954813957214355)
# (15, 4.1187334060668945)
# (16, 3.044092893600464)
# (17, 2.258174180984497)
# (18, 1.6808143854141235)
# (19, 1.2549378871917725)
# (20, 0.9396288394927979)
# (21, 0.7053883075714111)
# (22, 0.5308268666267395)
# (23, 0.4003649652004242)
# (24, 0.3026030957698822)
# (25, 0.22916105389595032)
# (26, 0.17386303842067719)
# (27, 0.132135808467865)
# (28, 0.10058683902025223)
# (29, 0.07668688148260117)
# (30, 0.058550264686346054)
# (31, 0.044763918966054916)
# (32, 0.03426747769117355)
# (33, 0.026264341548085213)
# (34, 0.020153604447841644)
# (35, 0.015481488779187202)
# (36, 0.011904941871762276)
# (37, 0.009163699112832546)
# (38, 0.007060266565531492)
# (39, 0.0054445150308310986)
# (40, 0.0042021856643259525)
# (41, 0.0032458684872835875)
# (42, 0.0025092505384236574)
# (43, 0.0019412284018471837)
# (44, 0.0015028152847662568)
# (45, 0.0011642040917649865)
# (46, 0.0009025185718201101)
# (47, 0.0007000838522799313)
# (48, 0.0005433508777059615)
# (49, 0.00042199587915092707)
# (50, 0.0003278994408901781)
# (51, 0.00025492170243524015)
# (52, 0.00019830299424938858)
# (53, 0.00015430834901053458)
# (54, 0.00012016046093776822)
# (55, 9.358990064356476e-05)
# (56, 7.293716771528125e-05)
# (57, 5.686939039151184e-05)
# (58, 4.434705988387577e-05)
# (59, 3.4606404369696975e-05)
# (60, 2.700920776987914e-05)
# (61, 2.1089743313496e-05)
# (62, 1.647435055929236e-05)
# (63, 1.2872524166596122e-05)
# (64, 1.0062071851280052e-05)
# (65, 7.87048975325888e-06)
# (66, 6.154187303764047e-06)
# (67, 4.815134161617607e-06)
# (68, 3.770035391426063e-06)
# (69, 2.9500233722501434e-06)
# (70, 2.3099823920347262e-06)
# (71, 1.8094476672558812e-06)
# (72, 1.4179604477249086e-06)
# (73, 1.1107320005976362e-06)
# (74, 8.707489769221866e-07)
# (75, 6.825589480285998e-07)
# (76, 5.355389021133306e-07)
# (77, 4.201035039841372e-07)
# (78, 3.2970049801406276e-07)
# (79, 2.587134702025651e-07)
# (80, 2.0301096981256705e-07)
# (81, 1.5934743657908257e-07)
# (82, 1.2514431091403821e-07)
# (83, 9.83484937933099e-08)
# (84, 7.715753724824026e-08)
# (85, 6.061545576585559e-08)
# (86, 4.780741491572371e-08)
# (87, 3.7518979922879225e-08)
# (88, 2.9626448849739973e-08)
# (89, 2.3222575862291706e-08)
# (90, 1.8285717828803172e-08)
# (91, 1.4448795937482828e-08)
# (92, 1.1268658006713395e-08)
# (93, 8.897713676958574e-09)
# (94, 6.9809220626382285e-09)
# (95, 5.4781006397774945e-09)
# (96, 4.297252775842253e-09)
# (97, 3.372051082806138e-09)
# (98, 2.6770283767518777e-09)
# (99, 2.114892039273286e-09)
# (100, 1.653785552946374e-09)
# (101, 1.3056463687988185e-09)
# (102, 1.0478357070908828e-09)
# (103, 8.471152668221293e-10)
# (104, 6.642755234764763e-10)
# (105, 5.357445043152609e-10)
# (106, 4.2056358395825555e-10)
# (107, 3.378816670895901e-10)
# (108, 2.741292748353885e-10)
# (109, 2.235321094889997e-10)
# (110, 1.8589811634495135e-10)
# (111, 1.5321974244919545e-10)
# (112, 1.2931759829637457e-10)
# (113, 1.0817248485839315e-10)
# (114, 9.286051094736791e-11)
# (115, 8.135130069586438e-11)
# (116, 7.035654003839653e-11)
# (117, 6.332502577865995e-11)
# (465, 1.4682103189472828e-12)
# (466, 1.316664876085949e-12)
# (467, 1.374174428761532e-12)
# (468, 1.4363469181405408e-12)
# (469, 1.5262749831351785e-12)
# (470, 1.5801207998294986e-12)
# (471, 1.6380189305637005e-12)
# (472, 1.6725191110539273e-12)
# (473, 1.6893945010282296e-12)
# (474, 1.518531177538418e-12)
# (475, 1.63821321959301e-12)
# (476, 1.6157312033443505e-12)
# (477, 1.5723214830815069e-12)
# (478, 1.52391575920785e-12)
# (479, 1.5174764656650241e-12)
# (480, 1.4735671450410992e-12)
# (481, 1.4807280835499315e-12)
# (482, 1.6307192141767901e-12)
# (483, 1.643819845867367e-12)
# (484, 1.5885862503922654e-12)
# (485, 1.661541780897946e-12)
# (486, 1.643809437526511e-12)
# (487, 1.690716360316924e-12)
# (488, 1.8099543131616658e-12)
# (489, 1.8544742564491346e-12)
# (490, 1.8645772859732235e-12)
# (491, 1.8712941352722057e-12)
# (492, 1.8365996657526695e-12)
# (493, 1.8146172498650914e-12)
# (494, 1.7350420145750833e-12)
# (495, 1.7971034816516296e-12)
# (496, 1.99902529425533e-12)
# (497, 1.7948691578145715e-12)
# (498, 1.6786565627119332e-12)
# (499, 1.7078137948961514e-12)

# %%
loss_fn(model(x), y)
# Out:
# Variable containing:
# 1.00000e-12 *
#   1.5334
# [torch.FloatTensor of size 1]

# %% [markdown]
# # А еще нам есть уже готовые оптимизаторы, такие как GD, SGD, ADAM, etc.

# %%
N, D_in, D_out = 64, 1000, 10

x = Variable(torch.randn(N, D_in))
y = Variable(torch.randn(N, D_out), requires_grad=False)

model = torch.nn.Sequential(
          torch.nn.Linear(D_in, D_out),

        )
loss_fn = torch.nn.MSELoss(size_average=False)

# %%
N, D_in, D_out = 64, 1000, 10

x = Variable(torch.randn(N, D_in))
y = Variable(torch.randn(N, D_out), requires_grad=False)

model = torch.nn.Sequential(
          torch.nn.Linear(D_in, D_out),

        )
loss_fn = torch.nn.MSELoss(size_average=False)

# model.parameters()

learning_rate = 1e-4
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

for t in range(500):
    y_pred = model(x)

    loss = loss_fn(y_pred, y)
    print(t, loss.data[0])

    optimizer.zero_grad()

    loss.backward()

    optimizer.step()
# Out:
# 0 774.2373046875
# 1 759.9967651367188
# 2 745.9061889648438
# 3 731.9664306640625
# 4 718.1824340820312
# 5 704.5537719726562
# 6 691.0833129882812
# 7 677.772216796875
# 8 664.6224365234375
# 9 651.6358642578125
# 10 638.813720703125
# 11 626.1564331054688
# 12 613.665771484375
# 13 601.3426513671875
# 14 589.1876831054688
# 15 577.201416015625
# 16 565.384033203125
# 17 553.7363891601562
# 18 542.2584228515625
# 19 530.950439453125
# 20 519.8123168945312
# 21 508.84368896484375
# 22 498.0445556640625
# 23 487.41436767578125
# 24 476.9522705078125
# 25 466.658203125
# 26 456.531005859375
# 27 446.5699768066406
# 28 436.7740478515625
# 29 427.1423034667969
# 30 417.67376708984375
# 31 408.36761474609375
# 32 399.2217712402344
# 33 390.23529052734375
# 34 381.4066162109375
# 35 372.73504638671875
# 36 364.2184753417969
# 37 355.85565185546875
# 38 347.6448059082031
# 39 339.5846252441406
# 40 331.6730041503906
# 41 323.90899658203125
# 42 316.2903137207031
# 43 308.8155517578125
# 44 301.4831848144531
# 45 294.29083251953125
# 46 287.2372741699219
# 47 280.3207092285156
# 48 273.5392150878906
# 49 266.8910217285156
# 50 260.37469482421875
# 51 253.9878387451172
# 52 247.7290496826172
# 53 241.59652709960938
# 54 235.58840942382812
# 55 229.70291137695312
